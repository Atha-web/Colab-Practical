# %%
import pandas as pd

df = pd.read_csv('cricketRecordsScore.csv')

df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s
# 0  54.04   51  68  14  2058  69
# 1  58.72   41  62  17  1509  73
# 2  45.97   45  58  16  1488  97
# 3  42.51   36  63   8  1654  21
# 4  46.95   33  57   9  1442  11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  107 non-null    object
#  1   Span    107 non-null    object
#  2   Mat     107 non-null    int64
#  3   Inns    107 non-null    int64
#  4   NO      107 non-null    int64
#  5   Runs    107 non-null    int64
#  6   HS      107 non-null    object
#  7   Ave     107 non-null    float64
#  8   BF      107 non-null    int64
#  9   SR      107 non-null    float64
#  10  100     107 non-null    int64
#  11  50      107 non-null    int64
#  12  0       107 non-null    int64
#  13  4s      107 non-null    int64
#  14  6s      107 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 12.7+ KB

# %%
df[['From', 'TO']]=df['Span'].str.split('-', expand=True)

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s  From    TO
# 0  54.04   51  68  14  2058  69  1989  2013
# 1  58.72   41  62  17  1509  73  1995  2012
# 2  45.97   45  58  16  1488  97  1995  2013
# 3  42.51   36  63   8  1654  21  1996  2012
# 4  46.95   33  57   9  1442  11  2006  2018

# %%
df[['P.Name', 'Country']]=df['Player'].str.split('(', expand=True)

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s  From    TO         P.Name   Country
# 0  54.04   51  68  14  2058  69  1989  2013  SR Tendulkar       IND)
# 1  58.72   41  62  17  1509  73  1995  2012    RT Ponting       AUS)
# 2  45.97   45  58  16  1488  97  1995  2013     JH Kallis    ICC/SA)
# 3  42.51   36  63   8  1654  21  1996  2012      R Dravid   ICC/IND)
# 4  46.95   33  57   9  1442  11  2006  2018       AN Cook       ENG)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  ...  50   0    4s  6s  From    TO P.Name Country    CC   ICC
# 0  54.04  ...  68  14  2058  69  1989  2013   IND)    None  IND)  None
# 1  58.72  ...  62  17  1509  73  1995  2012   AUS)    None  AUS)  None
# 2  45.97  ...  58  16  1488  97  1995  2013    ICC     SA)   ICC   SA)
# 3  42.51  ...  63   8  1654  21  1996  2012    ICC    IND)   ICC  IND)
# 4  46.95  ...  57   9  1442  11  2006  2018   ENG)    None  ENG)  None
#
# [5 rows x 21 columns]

# %%
df.drop(columns=['CC','ICC'])
# Out:
#                  Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0    SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1      RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2    JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3    R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4         AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
# ..                  ...        ...  ...   ...  ..    ...   ...    ...    ...
# 102     JH Edrich (ENG)  1963-1976   77   127   9   5138  310*  43.54  12102
# 103   Tamim Iqbal (BAN)  2008-2023   70   134   2   5134   206  38.89   8852
# 104    A Ranatunga (SL)  1982-2000   93   155  12   5105  135*  35.69   8672
# 105     AM Rahane (IND)  2013-2023   85   144  12   5077   188  38.46  10256
# 106  Zaheer Abbas (PAK)  1969-1985   78   124  11   5062   274  44.79   6935
#
# ...

# %%
df=df.drop(columns=['P.Name','Country','CC','ICC'])

# %%
df.head()
# Out:
#                Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437
# 1    RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85  22782
# 2  JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37  28903
# 3  R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31  31258
# 4       AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35  26562
#
#       SR  100  50   0    4s  6s  From    TO
# 0  54.04   51  68  14  2058  69  1989  2013
# 1  58.72   41  62  17  1509  73  1995  2012
# 2  45.97   45  58  16  1488  97  1995  2013
# 3  42.51   36  63   8  1654  21  1996  2012
# 4  46.95   33  57   9  1442  11  2006  2018

# %%
df=df.drop(columns='Span')

# %%
df.head()
# Out:
#                Player  Mat  Inns  NO   Runs    HS    Ave     BF     SR  100  \
# 0  SR Tendulkar (IND)  200   329  33  15921  248*  53.78  29437  54.04   51
# 1    RT Ponting (AUS)  168   287  29  13378   257  51.85  22782  58.72   41
# 2  JH Kallis (ICC/SA)  166   280  40  13289   224  55.37  28903  45.97   45
# 3  R Dravid (ICC/IND)  164   286  32  13288   270  52.31  31258  42.51   36
# 4       AN Cook (ENG)  161   291  16  12472   294  45.35  26562  46.95   33
#
#    50   0    4s  6s  From    TO
# 0  68  14  2058  69  1989  2013
# 1  62  17  1509  73  1995  2012
# 2  58  16  1488  97  1995  2013
# 3  63   8  1654  21  1996  2012
# 4  57   9  1442  11  2006  2018

# %%
df[['P.Name', 'Country']]=df['Player'].str.split('(', expand= True)

# %%
df.head()
# Out:
#                Player  Mat  Inns  NO   Runs    HS    Ave     BF     SR  100  \
# 0  SR Tendulkar (IND)  200   329  33  15921  248*  53.78  29437  54.04   51
# 1    RT Ponting (AUS)  168   287  29  13378   257  51.85  22782  58.72   41
# 2  JH Kallis (ICC/SA)  166   280  40  13289   224  55.37  28903  45.97   45
# 3  R Dravid (ICC/IND)  164   286  32  13288   270  52.31  31258  42.51   36
# 4       AN Cook (ENG)  161   291  16  12472   294  45.35  26562  46.95   33
#
#    50   0    4s  6s  From    TO         P.Name   Country   ICC    CC
# 0  68  14  2058  69  1989  2013  SR Tendulkar       IND)  IND)  None
# 1  62  17  1509  73  1995  2012    RT Ponting       AUS)  AUS)  None
# 2  58  16  1488  97  1995  2013     JH Kallis    ICC/SA)   ICC   SA)
# 3  63   8  1654  21  1996  2012      R Dravid   ICC/IND)   ICC  IND)
# 4  57   9  1442  11  2006  2018       AN Cook       ENG)  ENG)  None

# %%
df['Country']=df['Country'].str.replace('ICC/','')

# %%
df.head()
# Out:
#                Player  Mat  Inns  NO   Runs    HS    Ave     BF     SR  100  \
# 0  SR Tendulkar (IND)  200   329  33  15921  248*  53.78  29437  54.04   51
# 1    RT Ponting (AUS)  168   287  29  13378   257  51.85  22782  58.72   41
# 2  JH Kallis (ICC/SA)  166   280  40  13289   224  55.37  28903  45.97   45
# 3  R Dravid (ICC/IND)  164   286  32  13288   270  52.31  31258  42.51   36
# 4       AN Cook (ENG)  161   291  16  12472   294  45.35  26562  46.95   33
#
#    50   0    4s  6s  From    TO         P.Name Country  H.SCORE
# 0  68  14  2058  69  1989  2013  SR Tendulkar      IND  Not-Out
# 1  62  17  1509  73  1995  2012    RT Ponting      AUS      Out
# 2  58  16  1488  97  1995  2013     JH Kallis       SA      Out
# 3  63   8  1654  21  1996  2012      R Dravid      IND      Out
# 4  57   9  1442  11  2006  2018       AN Cook      ENG      Out

# %%
df['Country']=df['Country'].str.replace(')','')
# Out:
# <ipython-input-81-e9e99d37d2de>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Country']=df['Country'].str.replace(')','')

# %%
df=df.drop(columns=['ICC','CC'])

# %%
import numpy as np
df['H.SCORE']=np.where(df['HS'].str.contains(r'\*'),'Not-Out','Out')

# %%
df.head()
